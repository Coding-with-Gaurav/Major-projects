# %% [markdown]
# ## Setup

# %%
# ! pip install python-magic-bin langchain-community python-magic
# !pip install "unstructured[pdf]"
# Out:
# Requirement already satisfied: unstructured[pdf] in c:\users\23146007\.conda\envs\kg\lib\site-packages (0.15.14)
# Requirement already satisfied: chardet in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (5.3.0)
# Requirement already satisfied: nltk in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: tabulate in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.9.0)
# Requirement already satisfied: requests in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (4.12.3)
# Requirement already satisfied: emoji in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (2.14.0)
# Requirement already satisfied: dataclasses-json in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (3.10.0)
# Requirement already satisfied: backoff in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.26.0)
# Requirement already satisfied: wrapt in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (4.66.5)
# Requirement already satisfied: psutil in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.0.1)
# Requirement already satisfied: onnx in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdf2image in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (20231228)
# Requirement already satisfied: pikepdf in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (9.3.0)
# Requirement already satisfied: pi-heif in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.18.0)
# Requirement already satisfied: pypdf in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (5.0.1)
# Requirement already satisfied: google-cloud-vision in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (3.7.4)
# Requirement already satisfied: effdet in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.4.1)
# Requirement already satisfied: unstructured-inference==0.7.36 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.7.36)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured[pdf]) (0.3.13)
# Requirement already satisfied: layoutparser in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.3.4)
# Requirement already satisfied: python-multipart in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.0.12)
# Requirement already satisfied: huggingface-hub in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.25.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (1.19.2)
# Requirement already satisfied: matplotlib in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (3.9.2)
# Requirement already satisfied: torch in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (2.4.1)
# Requirement already satisfied: timm in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (1.0.11)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (4.45.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (10.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from beautifulsoup4->unstructured[pdf]) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from dataclasses-json->unstructured[pdf]) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Requirement already satisfied: torchvision in c:\users\23146007\.conda\envs\kg\lib\site-packages (from effdet->unstructured[pdf]) (0.19.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from effdet->unstructured[pdf]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.21.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (5.28.2)
# Requirement already satisfied: six in c:\users\23146007\.conda\envs\kg\lib\site-packages (from langdetect->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: click in c:\users\23146007\.conda\envs\kg\lib\site-packages (from nltk->unstructured[pdf]) (8.1.7)
# Requirement already satisfied: joblib in c:\users\23146007\.conda\envs\kg\lib\site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from nltk->unstructured[pdf]) (2024.9.11)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pdfminer.six->unstructured[pdf]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pdfminer.six->unstructured[pdf]) (43.0.1)
# Requirement already satisfied: Deprecated in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pikepdf->unstructured[pdf]) (1.2.14)
# Requirement already satisfied: olefile in c:\users\23146007\.conda\envs\kg\lib\site-packages (from python-oxmsg->unstructured[pdf]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from requests->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from requests->unstructured[pdf]) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\23146007\.conda\envs\kg\lib\site-packages (from tqdm->unstructured[pdf]) (0.4.6)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.9.2)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.65.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.67.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.67.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (4.9)
# Requirement already satisfied: anyio in c:\users\23146007\.conda\envs\kg\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\23146007\.conda\envs\kg\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\23146007\.conda\envs\kg\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.14.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\23146007\.conda\envs\kg\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.2)
# Requirement already satisfied: coloredlogs in c:\users\23146007\.conda\envs\kg\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\23146007\.conda\envs\kg\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (24.3.25)
# Requirement already satisfied: sympy in c:\users\23146007\.conda\envs\kg\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (3.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured[pdf]) (2.23.4)
# Requirement already satisfied: safetensors in c:\users\23146007\.conda\envs\kg\lib\site-packages (from timm->unstructured-inference==0.7.36->unstructured[pdf]) (0.4.5)
# Requirement already satisfied: filelock in c:\users\23146007\.conda\envs\kg\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.16.1)
# Requirement already satisfied: networkx in c:\users\23146007\.conda\envs\kg\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.4)
# Requirement already satisfied: jinja2 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\23146007\.conda\envs\kg\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (2024.9.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.7.36->unstructured[pdf]) (0.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: scipy in c:\users\23146007\.conda\envs\kg\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (1.14.1)
# Requirement already satisfied: pandas in c:\users\23146007\.conda\envs\kg\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: iopath in c:\users\23146007\.conda\envs\kg\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\users\23146007\.conda\envs\kg\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (0.11.4)
# Requirement already satisfied: pycparser in c:\users\23146007\.conda\envs\kg\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.6.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (10.0)
# Requirement already satisfied: portalocker in c:\users\23146007\.conda\envs\kg\lib\site-packages (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from jinja2->torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2024.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (4.30.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf]) (3.5.4)
# Requirement already satisfied: pywin32>=226 in c:\users\23146007\.conda\envs\kg\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (307)

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
# Dir PDF Loader
loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader(".\data_input\cureus\Yoga.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
# Number of chunks =  39
# BRANCHES OF AYURVEDA:
#
# Ayurveda is divided into eight components; these components are:
#
# ❖ Kaya Chikitsa (Internal Medicine) ❖ Bala Chikitsa (Treatment of Children / Pediatrics) ❖ Graha Chikitsa (Demonology / Psychology) ❖ Urdhvaanga Chikitsa (Treatment of disease above the clavicle) ❖ Shalya Chikitsa (Surgery) ❖ Agada Tantra / Visha Chikitsa: Toxicology ❖ Jara / Rasayana Tantra: Geriatrics
#
# 1
#
# ❖ Vajikarana: Reproductive sciences
#
# TREATMENT MODALITIES:
#
# Nidan Parivarjan(Avoidance of the disease-causing and aggravating factors)
#
# Nidan Parivarjan is to avoid the disease-causing factors in the diet and lifestyle of the patients. It encompasses the idea of refraining from the precipitating or aggravating factors of the disease.
#
# Shamana Therapy (Palliative Treatment)
#
# Shamana therapy suppresses vitiated humour (Doshas). The process by which vitiated humour subsides or returns to normal without creating an imbalance of other humours is known as Shamana. This treatment is achieved by using appetizers, digestives drugs, exercise, exposure to sun and fresh air, etc. Palliatives and sedatives are used in this form of treatment.
#
# Shodhana therapy (Purification Treatment)
#
# Shodhana therapy aims at the removal of the causative factors of somatic and psychosomatic diseases. The process includes internal and external purification. The usual practices involved are Panchkarma & Pre-panchakarma procedures.
#
# Satvavajaya (Psychotherapy)

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (39, 3)
#                                                 text  \
# 0  AYURVEDA\n\nINTRODUCTION\n\nAyurveda is the sc...
# 1  According to Ayurveda, everything in Universe ...
# 2  that governs metabolism is called Agni, which ...
# 3  BRANCHES OF AYURVEDA:\n\nAyurveda is divided i...
# 4  Satvavajaya (Psychotherapy)\n\nSatvavajaya tre...
#
#                            source                          chunk_id
# 0  data_input\cureus\AYURVEDA.pdf  7b0299dc89bb4a5c9c95e53e1c5186ea
# 1  data_input\cureus\AYURVEDA.pdf  f4ab7571bc644ab1900704b11583b2ed
# 2  data_input\cureus\AYURVEDA.pdf  ce9c6686673c402fb76461862d6eabbc
# 3  data_input\cureus\AYURVEDA.pdf  eb955a6fd22f4a5bbc11fa067d3493a6
# 4  data_input\cureus\AYURVEDA.pdf  3752c074bfa5433c967f963c0ae696c3

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#    {
#        "node_1": "positive health",
#        "node_2": "Dosha Dhatu Samya",
#        "edge": "Positive health is defined as Dosha Dhatu Samya in Ayurveda, which represents a well-balanced metabolism."
#    },
#    {
#        "node_1": "positive health",
#        "node_2": "prasanna Atma Indriya Manah",
#        "edge": "Positive health also includes prasanna Atma Indriya Manah, which refers to a happy state of the soul, senses and mind in Ayurveda."
#    },
#    {
#        "node_1": "Dharma",
#        "node_2": "positive health",
#        "edge": "In Ayurveda, attaining Dharma is not possible without sound positive health."
#    },
#    {
#        "node_1": "Artha",
#        "node_2": "positive health",
#        "edge": "Similarly, achieving Artha, which refers to prosperity and wealth, is also dependent on positive health in Ayurveda."
#    },
#    {
#        "node_1": "Kama",
#        "node_2": "positive health",
#        "edge": "Lastly, Kama or pleasures are also related to positive health in Ayurveda as a healthy body leads to a healthy mind and senses, allowing one to enjoy life's pleasures fully."
#    }
# ][
#    {
#        "node_1": "Akasha",
#        "node_2": "Universe",
#        "edge": "According to Ayurveda, everything in Universe is made of the Panchamahabhutas (five basic elements of life) and Akasha represents Space."
#    },
#    {
#        "node_1": "Vayu",
#        "node_2": "Universe",
#        "edge": "According to Ayurveda, everything in Universe is made of the Panchamahabhutas (five basic elements of life) and Vayu represents Air."
#    },
#    {
#        "node_1": "Teja",
#        "node_2": "Universe",
#        "edge": "According to Ayurveda, everything in Universe is made of the Panchamahabhutas (five basic elements of life) and Teja represents Fire."
#    },
#    {
#        "node_1": "Jala",
#        "node_2": "Universe",
#        "edge": "According to Ayurveda, everything in Universe is made of the Panchamahabhutas (five basic elements of life) and Jala represents Water."
#    },
#    {
#        "node_1": "Prithvi",
#        "node_2": "Universe",
#        "edge": "According to Ayurveda, everything in Universe is made of the Panchamahabhutas (five basic elements of life) and Prithvi represents Earth."
#    },
#    {
#        "node_1": "Vata",
#        "node_2": "Tridosas",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Pitta",
#        "node_2": "Tridosas",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Kapha",
#        "node_2": "Tridosas",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Rasa",
#        "node_2": "Saptadhatu",
#        "edge": "In Ayurveda, the structural and supporting units of the body are called Dhatu; these are seven in numbers (Saptadhatu)."
#    },
#    {
#        "node_1": "Mama",
#        "node_2": "Rasa",
#        "edge": "The primary Malas (waste products) Purisha (faeces), Mutra (urine), and Sveda (sweat) are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Rakta",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Mama",
#        "node_2": "Rakta",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Mamsa",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Medas",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Asthi",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Shukra",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Dhatu",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Pinda",
#        "node_2": "Mama",
#        "edge": "In Ayurveda, Ojas is responsible for consciousness, purity in thoughts, health, positivity in feelings in every situation, better immunity, longevity, intelligence, and memory. The three primary Malas (waste products) are Purisha (faeces), Mutra (urine), and Sveda (sweat). These are the waste products of food and the Dhatus (tissues) produced during the normal digestive and metabolic process."
#    },
#    {
#        "node_1": "Agni",
#        "node_2": "Digestion",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Life Force",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Samana",
#        "node_2": "Agni",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Agni",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Agni",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Agni",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Samana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Vyana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Vyana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Samana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Vyana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Samana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Vyana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Prana",
#        "node_2": "Udana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Vyana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Apana",
#        "node_2": "Samana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    },
#    {
#        "node_1": "Udana",
#        "node_2": "Apana",
#        "edge": "In Ayurveda, the Doshas are responsible for the physiological and psychological functions within the body and mind as dynamic forces that determine growth and decay."
#    }
# ][
#    {
#        "node_1": "Agni",
#        "node_2": "metabolism",
#        "edge": "The governance of metabolism in the body is called Agni."
#    },
#    {
#        "node_1": "Agni",
#        "node_2": "transformations",
#        "edge": "Agni is responsible for all the transformations in the body and mind."
#    },
#    {
#        "node_1": "digestion",
#        "node_2": "Agni",
#        "edge": "Digestion is one of the transformations that depend on Agni."
#    },
#    {
#        "node_1": "absorption of food",
#        "node_2": "Agni",
#        "edge": "Absorption of food is another transformation that depends on Agni."
#    },
#    {
#        "node_1": "cellular transformations",
#        "node_2": "Agni",
#        "edge": "Cellular transformations also depend on Agni."
#    },
#    {
#        "node_1": "Agni",
#        "node_2": "body and mind",
#        "edge": "Agni is responsible for the transformations in both the body and the mind."
#    },
#    {
#        "node_1": "Srotas",
#        "node_2": "inner transport system",
#        "edge": "The inner transport system of the body that provides a platform for activities of important bio-factors like three Dosha, seven Dhatu, Ojas, Agni, thoughts, and emotions is called Srotas."
#    },
#    {
#        "node_1": "Srotas",
#        "node_2": "proper functioning",
#        "edge": "Proper functioning of Srotas is necessary for transporting different materials to the site of their requirement."
#    },
#    {
#        "node_1": "Srotas",
#        "node_2": "blockage",
#        "edge": "The blockage of Srotas causes many diseases."
#    }
# ][
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Internal Medicine (Kaya Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Internal Medicine (Kaya Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Treatment of Children / Pediatrics (Bala Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Treatment of Children / Pediatrics (Bala Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Demonology / Psychology (Graha Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Demonology / Psychology (Graha Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Treatment of disease above the clavicle (Urdhvaanga Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Treatment of disease above the clavicle (Urdhvaanga Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Surgery (Shalya Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Surgery (Shalya Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Toxicology (Agada Tantra: Visha Chikitsa)",
#        "edge": "Ayurveda is divided into eight components, one of which is Toxicology (Agada Tantra: Visha Chikitsa)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Geriatrics (Jara / Rasayana Tantra)",
#        "edge": "Ayurveda is divided into eight components, one of which is Geriatrics (Jara / Rasayana Tantra)."
#    },
#    {
#        "node_1": "Ayurveda",
#        "node_2": "Reproductive sciences (Vajikarana)",
#        "edge": "Ayurveda includes Reproductive sciences (Vajikarana)."
#    },
#    {
#        "node_1": "Nidan Parivarjan",
#        "node_2": "Ayurveda",
#        "edge": "Nidan Parivarjan(Avoidance of the disease-causing and aggravating factors) is a part of Ayurveda."
#    },
#    {
#        "node_1": "Shamana Therapy",
#        "node_2": "Palliative Treatment",
# ...
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#    {
#       "node_1": "Real-time Yoga recognition using deep learning",
#       "node_2": "Yoga Posture Detection and Correction System",
#       "edge": "Both papers handle real-time detection, estimation, and correction of yoga poses through the implementation of techniques from both machine learning and deep learning."
#    },
#
#
#
# [
#    {
#        "node_1": "YogaPoseNet",
#        "node_2": "Real-Time Detection",
#        "edge": "YogaPoseNet is a deep learning network developed by Roy et al. (2021) for real-time detection of yoga postures."
#    },
#    {
#        "node_1": "YogaPoseNet",
#        "node_2": "Recognition",
#        "edge": "YogaPoseNet is also capable of recognizing yoga postures in addition to detecting them."
#    },
#    {
#        "node_1": "Bhattacharyya et al. (2021)",
#        "node_2": "Yoga Pose Detection",
#        "edge": "Bhattacharya et al. (2021) proposed a method for detecting yoga poses using convolutional neural networks."
#    },
#    {
#        "node_1": "International Conference on Computer Vision and Pattern Recognition",
#        "node_2": "Yoga Pose Detection",
#        "edge": "Bhattacharya et al. (2021) presented their work on yoga pose detection at the International Conference on Computer Vision and Pattern Recognition."
#    }
# ](416, 7)
#             node_1                       node_2  \
# 0  positive health            dosha dhatu samya
# 1  positive health  prasanna atma indriya manah
# 2           dharma              positive health
# 3            artha              positive health
# 4             kama              positive health
#
#                                                 edge  \
# 0  Positive health is defined as Dosha Dhatu Samy...
# 1  Positive health also includes prasanna Atma In...
# 2  In Ayurveda, attaining Dharma is not possible ...
# 3  Similarly, achieving Artha, which refers to pr...
# 4  Lastly, Kama or pleasures are also related to ...
#
#                            chunk_id node_3 edge_1  count
# 0  7b0299dc89bb4a5c9c95e53e1c5186ea    NaN    NaN      4
# 1  7b0299dc89bb4a5c9c95e53e1c5186ea    NaN    NaN      4
# 2  7b0299dc89bb4a5c9c95e53e1c5186ea    NaN    NaN      4
# 3  7b0299dc89bb4a5c9c95e53e1c5186ea    NaN    NaN      4
# 4  7b0299dc89bb4a5c9c95e53e1c5186ea    NaN    NaN      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#            node_1                                             node_2  \
# 5050  yogaposenet                        bhattacharyya et al. (2021)
# 5051  yogaposenet  international conference on computer vision an...
# 5052  yogaposenet                                real-time detection
# 5053  yogaposenet                                        recognition
# 5054  yogaposenet                                yoga pose detection
#
#                                                chunk_id  count  \
# 5050  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...      2
# 5051  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...      2
# 5052  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...      2
# 5053  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...      2
# 5054  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...      4
#
#                       edge
# 5050  contextual proximity
# 5051  contextual proximity
# 5052  contextual proximity
# 5053  contextual proximity
# 5054  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                              node_1  \
# 0                                  3d landmark data
# 1     3d landmark data produced by blaze pose model
# 2                                            99.49%
# 3                                            99.49%
# 4                                            99.70%
# ...                                             ...
# 1833                                    yogaposenet
# 1834                                    yogaposenet
# 1835                                    yogaposenet
# 1836                                    yogaposenet
# 1837                                    yogaposenet
#
#                                                  node_2  \
# 0                                      blaze pose model
# 1                                      blaze pose model
# 2                                                  cnns
# 3                             monitoring yoga positions
# 4                                                  cnns
# ...                                                 ...
# 1833                        bhattacharyya et al. (2021)
# 1834  international conference on computer vision an...
# 1835                                real-time detection
# 1836                                        recognition
# 1837                                yoga pose detection
#
#                                                chunk_id  \
# 0     ecffc8050b5d45c0979134853a8107fc,ecffc8050b5d4...
# 1     ecffc8050b5d45c0979134853a8107fc,ecffc8050b5d4...
# 2     5df2d37aa501404bad76ac24582b0ecc,5df2d37aa5014...
# 3     5df2d37aa501404bad76ac24582b0ecc,5df2d37aa5014...
# 4     5df2d37aa501404bad76ac24582b0ecc,5df2d37aa5014...
# ...                                                 ...
# 1833  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...
# 1834  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...
# 1835  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...
# 1836  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...
# 1837  544f3b1d67064b9b972a17a8b7d887e8,544f3b1d67064...
#
#                                                    edge  count
# 0     Produced by Blaze pose model without requiring...      6
# 1                                  contextual proximity      2
# 2                                  contextual proximity      2
# 3                                  contextual proximity      2
# 4                                  contextual proximity      2
# ...                                                 ...    ...
# 1833                               contextual proximity      2
# 1834                               contextual proximity      2
# 1835  YogaPoseNet is a deep learning network develop...      6
# 1836  YogaPoseNet is also capable of recognizing yog...      6
# 1837                               contextual proximity      4
#
# [1838 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (350,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  34
# [['3d landmark data', '3d landmark data produced by blaze pose model', 'blaze pose model', 'deep learning and machine learning models', 'existing pose estimation frameworks', 'media pipe blaze pose model', 'real-time yoga pose detection', 'real-time yoga/fitness applications', 'single person detections', 'xgboost classifier'], ['99.49%', '99.70%', 'asanas', 'body configuration estimation', "calculates each yoga pose's probability for the current image sequence", 'cnn', 'cnn and lstm models', 'cnn architecture', 'cnns', 'colour picture', 'confusion matrix', 'cross-platform media pipe library', 'database', 'deep learning', 'deep learning model', "discussion of approach's limitations", 'epipolar posture', 'exponential function of to determine the probability of each yoga pose', 'extracting key points', 'features', 'forecasting asanas', 'general positions', 'half-moon pose', 'highest probability', 'joints', 'json file containing joint position values', 'key point extraction', 'key points', 'key points extraction', 'last layer', 'lstm', 'machine learning', 'maintaining good form', 'major joints', 'media pipe', 'mediapipe', 'model', 'monitoring yoga positions', 'mountain pose', 'open pose', 'pattern', 'photos', 'points on the human body', 'pose correction', 'pose net', 'pose prediction', 'potential improvements', 'pre-processing techniques', 'primary points', 'publication [10]', 'real-time monitoring', 'recall, precision, sensitivity', 's-vyasa deemed to university', 'sentiment analysis', 'seven yoga poses', 'softmax activation function', 'softmax level', 'study', 'suggested models', 'testing accuracy', 'time distributed layer combination with cnn', 'training accuracy', 'tree posture', 'triangle pose', 'upadhyay, a:2023', 'user', 'user position', 'variance', 'video frames', 'video images or time series data', 'y_pn_mssd', 'yoga pose', 'yoga pose recognition', 'yoga positions', 'yoga posture recognition and classification', 'yoga postures tracking', 'yoga practices'], ['a survey on yogic posture recognition', 'deep learning-based yoga posture recognition using the y_pn-mssd model for yoga practitioners healthcare', 'estimation of yoga postures using machine learning techniques international journal of yoga ', 'real-time advanced yoga pose recognition and correction for smart healthcare.', 'surya namskar', 'yoga pose estimation and feedback generation using deep learning ijcs', 'yoga pose monitoring system using deep learning researchsquare ', 'yoga posture detection and correction system international reserch journal of modern education and technology '], ['abhilasha patil', 'author citation', 'conference paper', 'department of information technology', 'doi: 10.1109/esci59607.2024.10497433', 'gmail email address', 'india', 'jspm’s rajashri shahu college of engineering', 'jspm’s rajashri shahu college of engineering, pune, india', 'march 2024', 'prachi kulkarni', 'pune', 'shailesh gawai', 'shraddha choudhari', 'siddhi bhabad', 'yoga pose recognition using deep learning'], ['absorption of food', 'agni', 'akasha', 'apana', 'asthi', 'blockage', 'body and mind', 'cellular transformations', 'dhatu', 'digestion', 'inner transport system', 'jala', 'kapha', 'life force', 'mama', 'mamsa', 'medas', 'metabolism', 'pinda', 'pitta', 'prana', 'prithvi', 'proper functioning', 'rakta', 'rasa', 'samana', 'saptadhatu', 'shukra', 'srotas', 'teja', 'transformations', 'tridosas', 'udana', 'universe', 'vata', 'vayu', 'vyana'], ['accuracy and recall', 'classification score', 'classification score, confusion matrix, true negatives, true positives, false negatives, and false positives', 'f1-score', 'false negatives', 'false positives', 'good fitting version loss curve', 'highest number of samples', 'iv. emperical analysis and result', 'learning curves', 'matrix diagonal', 'model accuracy', 'model loss curve', 'precision', 'recall', 'true negatives', 'true positives', 'yoga classification system'], ['accuracy rating', 'controlled breathing', 'data augmentation ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                               node    color  group
# 0                                 3d landmark data  #c457db      1
# 1    3d landmark data produced by blaze pose model  #c457db      1
# 2                                 blaze pose model  #c457db      1
# 3        deep learning and machine learning models  #c457db      1
# 4              existing pose estimation frameworks  #c457db      1
# ..                                             ...      ...    ...
# 345                                     rgb images  #db57db     32
# 346                popularization of yoga practice  #7e57db     33
# 347                      self-study yoga programme  #7e57db     33
# 348                       yoga pose classification  #9557db     34
# 349                       yogaposenet architecture  #9557db     34
#
# [350 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
